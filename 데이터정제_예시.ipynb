# %% [markdown]
# <a href="https://colab.research.google.com/github/donghyundavidchoi/Data_Analysis/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A0%95%EC%A0%9C_%EC%98%88%EC%8B%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # mtcars 데이터셋의 qsec 칼럼을 최소최대 척도(Min-Max Scale)로 변환한 후 0.5보다 큰 값을 가지는 레코드 수를 구하시오.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import minmax_scale

# %%
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/Data_Analysis/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d ruiromanini/mtcars
# Out:
# mtcars.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/mtcars.zip
# Out:
# Archive:  /content/mtcars.zip
# replace mtcars.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: mtcars.csv

# %%
data = pd.read_csv('/content/mtcars.csv')

# %%
data
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# -------------

# %% [markdown]
# # qsec을 Min-Max Scale로 변환

# %%
# 원하는 위치에 새로운 컬럼을 생성하려는 경우
data.insert(8, 'qsec_minmax', minmax_scale(data['qsec']))

# %%
# 순서를 지정하지 않고 마지막 자리에 새로 컬럼을 생성하는 경우
# data['qsec_minmax'] = minmax_scale(data['qsec'])

# %%
data
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60
# ...

# %% [markdown]
# ------------------

# %% [markdown]
# # 0.5보다 큰 qsex_minmax의 개수 구하기

# %%
print(sum(data['qsec_minmax'] > 0.5))
# Out:
# 9
